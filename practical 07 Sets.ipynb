# %%
#sets
#unorderd and immutable collection of items
#list and tuple are oredrd

l1 =[1,2,3,4]
print(l1)
# Out:
# [1, 2, 3, 4]

# %%
t1 =(7,5,8,3)
print(t1)
# Out:
# (7, 5, 8, 3)

# %%
#set={1,2,3,2}
#it start with curly brackets
#it does not allow duplicates values
#use cases
#it help to remove duplicate values
#Union, intersection, and difference(mathmatically operation)

# %%
my_set = {1,2,3,4}
print(my_set)
# Out:
# {1, 2, 3, 4}

# %%
my_set2 = {1,2,3,4,2,5,3,6,7,8}
print(my_set2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
fruits = {'apple','banana','guava'}
print(fruits)
# Out:
# {'banana', 'guava', 'apple'}

# %%
fruits = {'apple','banana','guava','apple'}
print(fruits)
# Out:
# {'banana', 'guava', 'apple'}

# %%
fruits = {'apple','banana','guava','APPLE','Banana'}
print(fruits)
# Out:
# {'Banana', 'guava', 'APPLE', 'banana', 'apple'}

# %%
#'set constructor'
#fruits =set()

# %%
letters = set('hello')
print(letters)
# Out:
# {'o', 'h', 'e', 'l'}

# %%
a = set("jaipur")
print(a)
# Out:
# {'u', 'i', 'a', 'p', 'r', 'j'}

# %%
a =set("123456789")
print(a)
# Out:
# {'5', '9', '4', '8', '3', '7', '6', '2', '1'}

# %%
empty_set=set()
print(type(empty_set))
# Out:
# <class 'set'>

# %%
#set operation
#add
#delete

# %%
#add

num ={1,2,3}
num.add(4)
print(num)             #set_name.add(element to be added)
# Out:
# {1, 2, 3, 4}

# %%
#remove

num.remove(3)
print(num)
# Out:
# {1, 2, 4}

# %%
my_dict={'name':'deendayal','city':'jaipur','age':25,'state':'Rajsthan','course':'Big Data','pin':243122}

# %%
print(my_dict)
# Out:
# {'name': 'deendayal', 'city': 'jaipur', 'age': 25, 'state': 'Rajsthan', 'course': 'Big Data', 'pin': 243122}

# %%
my_dict['name']
# Out:
# 'deendayal'

# %%
my_dict['state']
# Out:
# 'Rajsthan'

# %%
my_dict['year']=2024

# %%
print(my_dict)
# Out:
# {'name': 'deendayal', 'city': 'jaipur', 'age': 25, 'state': 'Rajsthan', 'course': 'Big Data', 'pin': 243122, 'year': 2024}

# %%
my_dict['State']='RJ'

# %%
my_dict['state']='RJS'

# %%
print(my_dict)
# Out:
# {'name': 'deendayal', 'city': 'jaipur', 'age': 25, 'state': 'RJS', 'course': 'Big Data', 'pin': 243122, 'year': 2024, 'State': 'RJ'}

# %%
#built in method
#keys()
#values()
#item()

print(my_dict.keys())
# Out:
# dict_keys(['name', 'city', 'age', 'state', 'course', 'pin', 'year', 'State'])

# %%
print(my_dict.values())
# Out:
# dict_values(['deendayal', 'jaipur', 25, 'RJS', 'Big Data', 243122, 2024, 'RJ'])

# %%
print(my_dict.items())
# Out:
# dict_items([('name', 'deendayal'), ('city', 'jaipur'), ('age', 25), ('state', 'RJS'), ('course', 'Big Data'), ('pin', 243122), ('year', 2024), ('State', 'RJ')])

# %%
#update()    #add multiple key value pairs/another dictonary in th existing diconary.

#clear()

my_dict.update({'ahagav':'havaf','anang':'annaaf','hggsh':'gssgjh'})

# %%
print(my_dict)
# Out:
# {'name': 'deendayal', 'city': 'jaipur', 'age': 25, 'state': 'RJS', 'course': 'Big Data', 'pin': 243122, 'year': 2024, 'State': 'RJ', 'ahagav': 'havaf', 'anang': 'annaaf', 'hggsh': 'gssgjh'}

# %%
my_dict.clear()               #will delete th element of the dictonary but the structure of the dictonary will stay in its place

# %%
print(my_dict)
# Out:
# {}

# %%
my_dictionary2 = {'name':'dd','class':12}

# %%
del my_dictionary2['class']   #del keyword can remove any key from the dictonary

# %%
print(my_dictionary2)
# Out:
# {'name': 'dd'}

# %%
Name=my_dictionary2.pop('name')

# %%
print(my_dictionary2)
# Out:
# {}

# %%
dt={'assad':'sdsfh','hffsf':'sgsgj'}
a=dt.pop('assad')

# %%
print(dt)
# Out:
# {'hffsf': 'sgsgj'}

# %%
a
# Out:
# 'sdsfh'

# %%
#Boolean data type 
#True/False

is_passes=True

# %%
#None datatype
#None

marks=None

# %%
x=10,20
type(x)
# Out:
# tuple

# %%
x[0]=2000
x.append(30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x[0]=2000
#       2 x.append(30)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# dictionary =>
# data type
# key:unique
# values :
# mutable
# no index here
# {}

# %%
mydictionary={1:"tushar",2:"aman"}
print(mydictionary)

# %%
mydictionary={1:"tushar",2:"aman"}
print(mydictionary[2])

# %%
mydictionary={1:"tushar",2:"aman"}
mydictionary[1]="usha"  #update
mydictionary[3]="isha"  #insert
print(mydictionary)

# %%
mydictionary.pop(1)
print(mydictionary)

# %%
mydictionary.update({1:"tushar"})
print(mydictionary)

# %%
for key in mydictionary:
    print(key, mydictionary[key])

# %%
for key in mydictionary.values():
    print(key)

# %%
for key in mydictionary.keys():
    print(key)

# %%
for date in mydictionary.items():
    print(date)

# %%
for date in mydictionary.items():
    key,value=data
    print(date,key, value)

# %%
dict1={"amount":100}
print(dict1)

# %%
dict1["amount"]+10

# %%
dict1={"amount":100}
dict1["amount"]=dict1["amount"]+10
print(dict1)

# %%
#key : count 
my_dict={"count":0}
for i in range(1,10):
    my_dict["count"]=my_dict["count"]+1
    print(my_dict)

# %%
my_dict1={"count":0}
for i in "hello":
    my_dict1["count"]=my_dict1["count"]+1
print(my_dict1)

# %%
my_dict1={}
for i in "hello":
    my_dict1[i]=1
print(my_dict1)

# %%
#write a program to check every vowel with total number of count.

my_dict={}
for i in 'helloeuu':
    if i in "aeiou":
        if i not in my_dict:
            my_dict[i]=1
        else:
            my_dict[i]=my_dict[i]+1
        
print(my_dict)

# %%
my_dict1={}
for char in "hello":
    if char not in my_dict1:
        my_dict1[char]=1
    else:
        my_dict1[char]=my_dict1[char]+1

print(my_dict1)

# %%
my_dict2={}
for char in "olleh":
    if char not in my_dict2:
        my_dict2[char]=1
    else:
        my_dict2[char]=my_dict2[char]+1

print(my_dict2)

# %%
my_dict1==my_dict2
